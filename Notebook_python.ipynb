# %% [markdown]
# <a href="https://colab.research.google.com/github/LucasRSS27/Flask-git-demo/blob/main/Notebook_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library("ggplot2", "readr")
